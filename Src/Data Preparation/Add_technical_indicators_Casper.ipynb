# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Technical indicators for price data

# %%
folder_src = "../../Data/Casper/Processed/"
folder_dest = "../../Data/Casper/Final/"

df_org = pd.read_csv(folder_src + "Market.csv")
df_org.rename({"current_price":"close"}, inplace=True, axis=1)

df = df_org[["DateTime", "close"]].copy()
df_org.head()
# Out:
#      DateTime     close    market_cap  total_volume     BTC_price  \
# 0  2021-06-01  0.307023  0.000000e+00  1.768548e+07  37340.679266
# 1  2021-06-02  0.294818  0.000000e+00  1.883809e+07  36680.068202
# 2  2021-06-03  0.322123  0.000000e+00  5.570588e+07  37685.717982
# 3  2021-06-04  0.319187  0.000000e+00  2.390519e+07  39151.316184
# 4  2021-06-05  0.297641  1.755354e+08  1.871341e+07  36938.720311
#
#    BTC_market_caps  BTC_total_volumes    ETH_price  ETH_market_caps  \
# 0     6.991386e+11       3.795080e+10  2708.429866     3.144632e+11
# 1     6.887264e+11       3.353691e+10  2632.656600     3.064888e+11
# 2     7.045313e+11       3.124069e+10  2717.154037     3.153133e+11
# 3     7.331507e+11       3.339672e+10  2858.276702     3.339646e+11
# 4     6.917475e+11       3.934549e+10  2694.497667     3.129911e+11
#
#    ETH_total_volumes   LTC_price  LTC_market_caps  LTC_total_volumes  \
# 0       4.444583e+10  187.466185     1.251382e+10       4.865806e+09
# 1       3.989865e+10  183.149690     1.222568e+10       4.336082e+09
# 2       3.914886e+10  188.047863     1.254675e+10       4.236639e+09
# 3       3.810466e+10  194.229586     1.296529e+10       4.414448e+09
# 4       3.999658e+10  179.207420     1.196253e+10       4.377618e+09
#
#    XRP_price  XRP_market_caps  XRP_total_volumes
# 0   1.041413     4.805455e+10       6.691380e+09
# 1   1.011334     4.667411e+10       6.148631e+09
# 2   1.025065     4.725685e+10       3.994210e+09
# 3   1.050720     4.849181e+10       4.088715e+09
# 4   0.970685     4.480910e+10       4.190246e+09

# %% [markdown]
# ### Rate of change (ROC)
#
# Calculated for lookback periods of 3, 7 and 30 days

# %%
df['ROC_3'] = (df.close / df.close.shift(3) - 1) * 100
df['ROC_7'] = (df.close / df.close.shift(7) - 1) * 100
df['ROC_30'] = (df.close / df.close.shift(30) - 1) * 100

# %% [markdown]
# ### Moving averages
#
# Here 2 types of moving averages are chosen: simple moving average and exponential moving average. For both MAs there are 3 sizes of the sliding windows: 3, 7 and 30 days

# %%
df['SMA_3'] = df.close.rolling(3).mean()
df['SMA_7'] = df.close.rolling(7).mean()
df['SMA_30'] = df.close.rolling(30).mean()


df['EMA_3'] = df.close.ewm(span=3).mean()
df['EMA_7'] = df.close.ewm(span=7).mean()
df['EMA_30'] = df.close.ewm(span=30).mean()

# %% [markdown]
# ### Moving Average Convergence Divergence (MACD)
#
# Comprised of the MACD line, the signal line and the histogram

# %%
df["MACD"] = df.EMA_7 - df.EMA_30

signal_period = 9
df["MACD_signal"] = df.MACD.ewm(span=signal_period, adjust=False).mean()
df["MACD_hist"] = df.MACD - df.MACD_signal

# %% [markdown]
# ### Relative strength index (RSI)
#
# Relative strength index is calculated for look back periods of 7 and 14 days.

# %%
def rsi(df, look_back):
    dfc = df.copy()
    dfc["priceDiff"] = dfc.close.diff()

    dfc['Gain'] = dfc.priceDiff.where(dfc.priceDiff > 0, 0)
    dfc['Loss'] = -dfc.priceDiff.where(dfc.priceDiff < 0, 0)

    avg_gain = dfc['Gain'].rolling(window=look_back).mean()
    avg_loss = dfc['Loss'].rolling(window=look_back).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
df['RSI_7'] = rsi(df, 7)
df['RSI_14'] = rsi(df, 14)

# %% [markdown]
# ### Rolling standard deviation
#
# Calculated for rolling windows of 3, 7 and 30 days.

# %%
df['STD_3'] = df.close.rolling(3).std()
df['STD_7'] = df.close.rolling(7).std()
df['STD_30'] = df.close.rolling(30).std()

# %%
df = df.drop("close", axis= 1)
df
# Out:
#        DateTime     ROC_3     ROC_7     ROC_30     SMA_3     SMA_7    SMA_30  \
# 0    2021-06-01       NaN       NaN        NaN       NaN       NaN       NaN
# 1    2021-06-02       NaN       NaN        NaN       NaN       NaN       NaN
# 2    2021-06-03       NaN       NaN        NaN  0.307988       NaN       NaN
# 3    2021-06-04  3.961963       NaN        NaN  0.312043       NaN       NaN
# 4    2021-06-05  0.957594       NaN        NaN  0.312984       NaN       NaN
# ..          ...       ...       ...        ...       ...       ...       ...
# 726  2023-05-28  8.320010  4.299057  -6.660722  0.050159  0.049385  0.052672
# 727  2023-05-29  8.249716  6.596239  -4.344533  0.051492  0.049849  0.052593
# 728  2023-05-30 -0.759752  3.595533 -14.384181  0.051364  0.050096  0.052313
# 729  2023-05-31 -6.706123 -3.505160 -23.402136  0.050207  0.049845  0.051821
# 730  2023-06-01 -9.461380 -0.682274 -19.924812  0.048552  0.049799  0.051427
#
#         EMA_3     EMA_7    EMA_30      MACD  MACD_signal  MACD_hist  \
# 0    0.307023  0.307023  0.307023  0.000000     0.000000   0.000000
# 1    0.298886  0.300049  0.300717 -0.000668    -0.000134  -0.000535
# 2    0.312165  0.309594  0.308333  0.001261     0.000145   0.001116
# 3    0.315910  0.313103  0.311324  0.001779     0.000472   0.001307
# 4    0.306481  0.308035  0.308211 -0.000176     0.000342  -0.000519
# ..        ...       ...       ...       ...          ...        ...
# 726  0.050583  0.049772  0.050360 -0.000588    -0.001188   0.000600
# 727  0.051520  0.050443  0.050496 -0.000052    -0.000961   0.000909
# 728  0.050679  0.050292  0.050453 -0.000161    -0.000801   0.000640
# 729  0.049502  0.049800  0.050316 -0.000516    -0.000744   0.000228
# 730  0.048498  0.049224  0.050134 -0.000910    -0.000777  -0.000133
#
#          RSI_7     RSI_14     STD_3     STD_7    STD_30
# 0          NaN        NaN       NaN       NaN       NaN
# 1          NaN        NaN       NaN       NaN       NaN
# 2          NaN        NaN  0.013678       NaN       NaN
# 3          NaN        NaN  0.014990       NaN       NaN
# 4          NaN        NaN  0.013368       NaN       NaN
# ..         ...        ...       ...       ...       ...
# 726  60.931380  55.274298  0.001671  0.001413  0.004872
# 727  66.277084  60.691839  0.001150  0.001820  0.004854
# 728  57.528829  52.972098  0.001362  0.001654  0.004760
# 729  42.042021  49.692090  0.002090  0.001785  0.004353
# 730  48.300717  48.112535  0.001189  0.001849  0.004184
#
# [731 rows x 18 columns]

# %%
df = df.loc[30:, ]
df.isnull().sum()
# Out:
# DateTime       0
# ROC_3          0
# ROC_7          0
# ROC_30         0
# SMA_3          0
# SMA_7          0
# SMA_30         0
# EMA_3          0
# EMA_7          0
# EMA_30         0
# MACD           0
# MACD_signal    0
# MACD_hist      0
# RSI_7          0
# RSI_14         0
# STD_3          0
# STD_7          0
# STD_30         0
# dtype: int64

# %% [markdown]
# ## Level the other data to same time interval

# %%
# Determine starting and end intervals and save TI data
START_DATE = min(df.DateTime)
END_DATE = max(df.DateTime)
print(START_DATE, END_DATE)

df.drop("DateTime", axis = 1, inplace=True)
df.to_csv(folder_dest + "TI.csv", index=False)
# Out:
# 2021-07-01 2023-06-01
# /tmp/ipykernel_3490669/2203419905.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("DateTime", axis = 1, inplace=True)

# %%
# Crop all other data sets so that they are on the same interval
for file in os.listdir(folder_src):
    df_temp = pd.read_csv(folder_src + file)
    df_temp = df_temp[(df_temp.DateTime >= START_DATE) & (df_temp.DateTime <= END_DATE)]
    df_temp.drop("DateTime", axis = 1, inplace=True)
    df_temp.to_csv(folder_dest + file, index=False)

# %%
for file in os.listdir(folder_dest):
    df_temp = pd.read_csv(folder_dest + file)
    print(file, df_temp.shape)
# Out:
# TI.csv (701, 17)
# Accounts.csv (701, 5)
# Staking.csv (701, 4)
# Market.csv (701, 15)
# Transactions.csv (701, 7)
