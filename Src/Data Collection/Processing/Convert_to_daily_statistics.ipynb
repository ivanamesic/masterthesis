# %%
import requests
import pandas as pd
import json
from datetime import datetime
from tqdm import tqdm

# %%
END_BLOCK = 3782050
root = "/mnt/Ivana/"
src_dir = root + "Data/Tezos/Raw_data/"
dest_dir = root + "Data/Tezos/Processed/"
final_dir = root + "Data/Tezos/Final/"

# %% [markdown]
# ## Convert contract raw data into per-block statistics

# %%
df = pd.read_csv("Data/Tezos/Raw_data/TZ_contract_data.csv")
df

# %%
df_contract_stats = df.groupby(["firstActivity", "kind"]).address.count().unstack().reset_index()
df_contract_stats.fillna(0, inplace=True)
df_contract_stats = df_contract_stats[["firstActivity", "asset", "delegator_contract", "smart_contract"]]
df_contract_stats.columns = ["level", "new_assets", "new_delegator_contracts", "new_smart_contracts"]
df_contract_stats.sort_values(by="level", ascending=True, inplace=True)

# %%
df_contract_stats["total_assets"] = df_contract_stats.new_assets.cumsum()
df_contract_stats["total_delegator_contracts"] = df_contract_stats.new_delegator_contracts.cumsum()
df_contract_stats["total_smart_contracts"] = df_contract_stats.new_smart_contracts.cumsum()

# %%
df_levels = pd.DataFrame({"level" : range(1,END_BLOCK+1)})
df_result = pd.merge(df_levels, df_contract_stats, how="left", on="level")

# %%
df_result[["new_assets", "new_delegator_contracts", "new_smart_contracts"]] = df_result[["new_assets", "new_delegator_contracts", "new_smart_contracts"]].fillna(0)
df_result[["total_assets", "total_delegator_contracts", "total_smart_contracts"]] = df_result[["total_assets", "total_delegator_contracts", "total_smart_contracts"]].fillna(method='ffill')

# %%
df_result.to_csv("Data/Tezos/Processed/Contracts_per_level.csv", index=False)

# %% [markdown]
# ## Daily statistics of supply

# %%
df = pd.read_csv(src_dir + "TZ_daily_statistics.csv")
df.drop(['totalBootstrapped', 'totalCommitments','totalRollupBonds', 'totalSmartRollupBonds'], axis=1, inplace=True)
df.to_csv(dest_dir + "TZ_supply.csv", index=False)

# %% [markdown]
# ## Convert voting periods

# %%
df = pd.read_csv(src_dir + "TZ_voting_periods.csv")
df_levels = pd.DataFrame({"level" : range(1,END_BLOCK+1)})
df
# Out:
#      index  epoch  firstLevel             startTime  lastLevel  \
# 0        0      0           1  2018-06-30T17:39:57Z      32768
# 1        1      1       32769  2018-07-24T22:20:27Z      65536
# 2        2      2       65537  2018-08-18T04:20:11Z      98304
# 3        3      3       98305  2018-09-11T00:13:14Z     131072
# 4        4      4      131073  2018-10-04T12:52:29Z     163840
# ..     ...    ...         ...                   ...        ...
# 98      98     46     3596289  2023-05-26T06:02:44Z    3678208
# 99      99     46     3678209  2023-06-09T14:37:38Z    3760128
# 100    100     47     3760129  2023-06-24T00:07:10Z    3842048
# 101    101     48     3842049  2023-07-08T11:38:15Z    3923968
# 102    102     49     3923969  2023-07-22T22:51:51Z    4005888
#
#                   endTime       kind        status dictator  totalBakers  ...  \
# 0    2018-07-24T22:19:27Z   proposal  no_proposals     none          8.0  ...
# 1    2018-08-18T04:17:56Z   proposal  no_proposals     none        425.0  ...
# 2    2018-09-11T00:12:14Z   proposal  no_proposals     none        448.0  ...
# 3    2018-10-04T12:51:29Z   proposal  no_proposals     none        411.0  ...
# 4    2018-10-27T21:31:14Z   proposal  no_proposals     none        446.0  ...
# ..                    ...        ...           ...      ...          ...  ...
# 98   2023-06-09T14:37:23Z  promotion       success     none        408.0  ...
# 99   2023-06-24T00:06:55Z   adoption       success     none          NaN  ...
# 100  2023-07-08T11:38:00Z   proposal  no_proposals     none        398.0  ...
# 101  2023-07-22T22:51:36Z   proposal  no_proposals     none        388.0  ...
# 102  2023-08-06T06:14:35Z   proposal        active     none        374.0  ...
#
#      supermajority  yayBallots  yayVotingPower  nayBallots  nayVotingPower  \
# 0              NaN         NaN             NaN         NaN             NaN
# 1              NaN         NaN             NaN         NaN             NaN
# 2              NaN         NaN             NaN         NaN             NaN
# 3              NaN         NaN             NaN         NaN             NaN
# 4              NaN         NaN             NaN         NaN             NaN
# ..             ...         ...             ...         ...             ...
# 98            80.0       122.0    2.318774e+14         1.0    1.595413e+11
# 99             NaN         NaN             NaN         NaN             NaN
# 100            NaN         NaN             NaN         NaN             NaN
# 101            NaN         NaN             NaN         NaN             NaN
# 102            NaN         NaN             NaN         NaN             NaN
#
#      passBallots  passVotingPower  yayRolls  nayRolls  passRolls
# 0            NaN              NaN       NaN       NaN        NaN
# 1            NaN              NaN       NaN       NaN        NaN
# 2            NaN              NaN       NaN       NaN        NaN
# 3            NaN              NaN       NaN       NaN        NaN
# 4            NaN              NaN       NaN       NaN        NaN
# ..           ...              ...       ...       ...        ...
# 98          28.0     1.809579e+14   38646.0      26.0    30159.0
# 99           NaN              NaN       NaN       NaN        NaN
# 100          NaN              NaN       NaN       NaN        NaN
# 101          NaN              NaN       NaN       NaN        NaN
# 102          NaN              NaN       NaN       NaN        NaN
#
# [103 rows x 28 columns]

# %%
df[df.status == "active"]
# Out:
#      index  epoch  firstLevel             startTime  lastLevel  \
# 102    102     49     3923969  2023-07-22T22:51:51Z    4005888
#
#                   endTime      kind  status dictator  totalBakers  ...  \
# 102  2023-08-06T06:14:35Z  proposal  active     none        374.0  ...
#
#      supermajority  yayBallots  yayVotingPower  nayBallots  nayVotingPower  \
# 102            NaN         NaN             NaN         NaN             NaN
#
#      passBallots  passVotingPower  yayRolls  nayRolls  passRolls
# 102          NaN              NaN       NaN       NaN        NaN
#
# [1 rows x 28 columns]

# %%
df[df.kind==].groupby("stat").status.unique()
# Out:
# kind
# adoption                                        [success]
# exploration        [success, no_quorum, no_supermajority]
# promotion                                       [success]
# proposal       [no_proposals, success, no_quorum, active]
# testing                                         [success]
# Name: status, dtype: object

# %%
for i, row in df.iterrows():
    proposal_success = (row["kind"] == "proposal") & (row["status"] == "success")
    adoption_success = row["kind"] == "adoption"
    testing_success = row["kind"] == "testing"


    ind = df_levels[(df_levels.level >= int(row["firstLevel"])) & (df_levels.level <= int(row["lastLevel"]))].index

    df_levels.loc[ind, "proposal_success"] = proposal_success
    df_levels.loc[ind, "adoption"] = adoption_success
    df_levels.loc[ind, "testing"] = testing_success
    df_levels.loc[ind, "voting_power"] = row["totalVotingPower"]

# %%
df_levels.to_csv(dest_dir + "Voting_by_block.csv", index = False)

# %% [markdown]
# ## Convert Baking data into daily statistics

# %%
df = pd.read_csv(src_dir + "Baking_data.csv")
df
# Out:
#            type               id    level             timestamp  \
# 0        baking  574317635043328  3550000  2023-05-18T01:53:16Z
# 1        baking  574317870972928  3550001  2023-05-18T01:53:31Z
# 2        baking  574318101659648  3550002  2023-05-18T01:53:46Z
# 3        baking  574318353317888  3550003  2023-05-18T01:54:01Z
# 4        baking  574318610219008  3550004  2023-05-18T01:54:16Z
# ...         ...              ...      ...                   ...
# 3789993  baking   57141751709696  1509995  2021-06-10T22:49:38Z
# 3789994  baking   57141825110016  1509996  2021-06-10T22:50:38Z
# 3789995  baking   57141977153536  1509997  2021-06-10T22:51:38Z
# 3789996  baking   57142062088192  1509998  2021-06-10T22:52:38Z
# 3789997  baking   57142166945792  1509999  2021-06-10T22:53:38Z
#
#                                                      block  \
# 0        BM96QfUaCfEi9Uyjz5Xu1hwrRGbF5tZPPE67w2ben4dqK7...
# 1        BKmxGhZdjhvAf8T3dSG2Y4DcXbZoEpf3F9aj7TFqQJ3nEu...
# 2        BMcZSjq1fknhkpywa9pFYzMnNY9aueSYkaLQKKbt4atZPL...
# 3        BMRgaMyzdScQDNUXXd1FHDhqTnodhmxC1hnsnPXvALCHqi...
# 4        BLq92KpqjaMxS4mbACt8SRk1o7LzHheNsRgj9nza266yMQ...
# ...                                                    ...
# 3789993  BLDSWFiFrh8fq9QqGSBPjsH3aPvrhX9pYMitsrghz2F26F...
# 3789994  BLJoBy3go3Rqs9T13KbMw3NgVMMKZoQniMdJ1LmL2H46Ws...
# 3789995  BMNDZQMftYSPb91XB1CAheXStXcDbBc988Ku38igCsiAMM...
# 3789996  BMbSH8GJ1PYsoiFDMFaLrj9tNKdpvLaCszUa3pTA5esucQ...
# 3789997  BLBUiVnuRuVdxHTEx5WegwXizxghDL57o3uTUv3MEfAGhj...
#
#                     proposer_alias                      proposer_address  \
# 0                    P2P Validator  tz1P2Po7YM526ughEsRbY4oR9zaUPDZjxFrb
# 1                          pos.dog  tz1VQnqCCqX4K5sP3FNkVSNKTdCAMJDd3E1n
# 2                              NaN  tz3QT9dHYKDqh563chVa6za8526ys1UKfRfL
# 3                        Everstake  tz1aRoaRhSpRYvFdyvgWLL6TGyRoGF51wDjM
# 4                      Happy Tezos  tz1WCd2jm4uSt4vntk4vSuUWoZQGhLcDuR9q
# ...                            ...                                   ...
# 3789993              Binance Baker  tz1S8MNvuFEUsWgjHvi3AxibRBf388NhT1q2
# 3789994                        NaN  tz3RKYFsLuQzKBtmYuLNas7uMu3AsYd4QdsA
# 3789995  Foundation baker 2 legacy  tz3bvNMQ95vfAYtG8193ymshqjSvmxiCUuR5
# 3789996                  Moonstake  tz1MQMiZHV8q4tTwUMWmS5Y3kaP6J2136iXr
# 3789997             Coinbase Baker  tz1irJKkXS2DBWkU1NnmFQx1c1L7pbGg4yhk
#
#                     producer_alias                      producer_address  \
# 0                    P2P Validator  tz1P2Po7YM526ughEsRbY4oR9zaUPDZjxFrb
# 1                          pos.dog  tz1VQnqCCqX4K5sP3FNkVSNKTdCAMJDd3E1n
# 2                              NaN  tz3QT9dHYKDqh563chVa6za8526ys1UKfRfL
# 3                        Everstake  tz1aRoaRhSpRYvFdyvgWLL6TGyRoGF51wDjM
# 4                      Happy Tezos  tz1WCd2jm4uSt4vntk4vSuUWoZQGhLcDuR9q
# ...                            ...                                   ...
# 3789993              Binance Baker  tz1S8MNvuFEUsWgjHvi3AxibRBf388NhT1q2
# 3789994                        NaN  tz3RKYFsLuQzKBtmYuLNas7uMu3AsYd4QdsA
# 3789995  Foundation baker 2 legacy  tz3bvNMQ95vfAYtG8193ymshqjSvmxiCUuR5
# 3789996                  Moonstake  tz1MQMiZHV8q4tTwUMWmS5Y3kaP6J2136iXr
# 3789997             Coinbase Baker  tz1irJKkXS2DBWkU1NnmFQx1c1L7pbGg4yhk
#
#          payloadRound  blockRound    deposit    reward    bonus    fees  \
# 0                   0           0          0   5000000  4939615    2254
# 1                   0           0          0   5000000  4939615    1179
# 2                   0           0          0   5000000  4954616    2447
# 3                   0           0          0   5000000  4956759    2410
# 4                   0           0          0   5000000  4956759    9554
# ...               ...         ...        ...       ...      ...     ...
# 3789993             0           0  512000000  30000000        0  167840
# 3789994             0           0  512000000  36250000        0  400997
# 3789995             0           0  512000000  38750000        0  232753
# 3789996             0           0  512000000  40000000        0  485086
# 3789997             0           0  512000000  38750000        0  400756
#
#                        baker_alias                         baker_address  \
# 0                    P2P Validator  tz1P2Po7YM526ughEsRbY4oR9zaUPDZjxFrb
# 1                          pos.dog  tz1VQnqCCqX4K5sP3FNkVSNKTdCAMJDd3E1n
# 2                              NaN  tz3QT9dHYKDqh563chVa6za8526ys1UKfRfL
# 3                        Everstake  tz1aRoaRhSpRYvFdyvgWLL6TGyRoGF51wDjM
# 4                      Happy Tezos  tz1WCd2jm4uSt4vntk4vSuUWoZQGhLcDuR9q
# ...                            ...                                   ...
# 3789993              Binance Baker  tz1S8MNvuFEUsWgjHvi3AxibRBf388NhT1q2
# 3789994                        NaN  tz3RKYFsLuQzKBtmYuLNas7uMu3AsYd4QdsA
# 3789995  Foundation baker 2 legacy  tz3bvNMQ95vfAYtG8193ymshqjSvmxiCUuR5
# 3789996                  Moonstake  tz1MQMiZHV8q4tTwUMWmS5Y3kaP6J2136iXr
# 3789997             Coinbase Baker  tz1irJKkXS2DBWkU1NnmFQx1c1L7pbGg4yhk
#
#          priority
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 3789993         0
# 3789994         0
# 3789995         0
# 3789996         0
# 3789997         0
#
# [3789998 rows x 18 columns]

# %%
df.timestamp = pd.to_datetime(df.timestamp, format="%Y-%m-%dT%H:%M:%SZ")
df["date"] = df.timestamp.apply(lambda x: x.date())

# %%
aggs = {
    "deposit" : ["mean", "sum"],
    "reward" : ["mean", "sum"],
    "bonus" : ["mean", "sum"],
    "fees" : ["mean", "sum"],
    "baker_address" : "nunique"
}
df_daily = df.groupby("date").aggregate(aggs)

# %%
cols = ["date", "avg_deposit", "deposit_total", "avg_reward", "reward_total", "avg_bonus", "bonus_total", "avg_fees", "fees_total", "nr_bakers"]
df_daily = df_daily.reset_index()
df_daily.columns = cols
df_daily
# Out:
#             date   avg_deposit  deposit_total  avg_reward  reward_total  \
# 0     2018-06-30  0.000000e+00              0         0.0             0
# 1     2018-07-01  0.000000e+00              0         0.0             0
# 2     2018-07-02  0.000000e+00              0         0.0             0
# 3     2018-07-03  3.243394e+06     4664000000         0.0             0
# 4     2018-07-04  8.000000e+06    11512000000         0.0             0
# ...          ...           ...            ...         ...           ...
# 1821  2023-06-25  0.000000e+00              0   5000000.0   28145000000
# 1822  2023-06-26  0.000000e+00              0   5000000.0   28165000000
# 1823  2023-06-27  0.000000e+00              0   5000000.0   28175000000
# 1824  2023-06-28  0.000000e+00              0   5000000.0   28515000000
# 1825  2023-06-29  0.000000e+00              0   5000000.0    8845000000
#
#          avg_bonus  bonus_total       avg_fees  fees_total  nr_bakers
# 0     0.000000e+00            0    2129.281915      800610          8
# 1     0.000000e+00            0    2500.078691     3590113          8
# 2     0.000000e+00            0    3236.193978     4621285          8
# 3     0.000000e+00            0    2303.459666     3312375          8
# 4     0.000000e+00            0    2294.140375     3301268          8
# ...            ...          ...            ...         ...        ...
# 1821  4.745639e+06  26713202190   22136.483923   124606268        189
# 1822  4.793497e+06  27001767855   18826.376886   106048981        196
# 1823  4.818843e+06  27154180158  179881.573736  1013632668        190
# 1824  4.869043e+06  27768149658   67342.705418   384055449        195
# 1825  4.881503e+06   8635379225   41764.625212    73881622        148
#
# [1826 rows x 10 columns]

# %%
df_daily.to_csv(final_dir + "TZ_baking_daily.csv", index=False)

# %% [markdown]
# ## Group blocks by month

# %%
df_blocks = pd.read_csv("../../Data/Tezos/Raw_data/TZ_Blocks.csv")

# %%
df_blocks.timestamp = pd.to_datetime(df_blocks.timestamp,  format="%Y-%m-%dT%H:%M:%SZ")
df_blocks.sort_values(by="timestamp", inplace=True)
df_blocks["month"] = df_blocks.timestamp.apply(lambda x: format(x, "%m-%Y"))

# %%
block_by_month = df_blocks.groupby("month").agg({"level":["min", "max"]}).reset_index()
block_by_month.columns = ["date", "startLevel", "endLevel"]
block_by_month["time"] = pd.to_datetime(block_by_month.date, format="%m-%Y")

# %%
block_by_month.sort_values(by="time", inplace=True)
block_by_month.to_csv("../../Data/Tezos/Processed/Blocks_by_month.csv", index=False)

# %% [markdown]
# ## OHLC

# %%
df = pd.read_csv(src_dir + "amCharts.csv")
df
# Out:
#                      date  weighted   close    high     low    open     volume
# 0     2017-06-24 02:06:00      2.20  2.2020  5.1540  1.4250  3.9540   28410.88
# 1     2017-06-25 02:06:00      3.02  3.0220  3.0250  2.0000  2.2020   39000.54
# 2     2017-06-26 02:06:00      1.94  1.9400  3.6570  1.9080  3.0220   16199.11
# 3     2017-06-27 02:06:00      3.59  3.5910  3.8760  2.0130  1.9400   42346.85
# 4     2017-06-28 02:06:00      2.32  2.3200  3.6600  2.2890  3.5910    6563.88
# ...                   ...       ...     ...     ...     ...     ...        ...
# 2239  2023-08-13 02:08:00      0.80  0.7940  0.8020  0.7891  0.7920  136339.09
# 2240  2023-08-14 02:08:00      0.80  0.7990  0.8070  0.7863  0.7940  282060.02
# 2241  2023-08-15 02:08:00      0.76  0.7640  0.7990  0.7337  0.7990  686183.36
# 2242  2023-08-16 02:08:00      0.74  0.7318  0.7677  0.7192  0.7640  724759.44
# 2243  2023-08-17 02:08:00      0.73  0.7300  0.7368  0.7248  0.7318  209698.82
#
# [2244 rows x 7 columns]

# %%
df.date = pd.to_datetime(df.date)
df.rename({"date":"timestamp"}, axis=1, inplace=True)

# %%
df["date"] = df.timestamp.apply(lambda x: x.date())
df_final = df[["date", "close", "high", "low", "open"]]

# %%
df_final.to_csv(dest_dir + "Cointg_OHLC.csv", index=False)
